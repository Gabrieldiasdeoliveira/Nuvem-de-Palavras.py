# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabrieldiasdeoliveira/Nuvem-de-Palavras.py/blob/main/Nuvem_de_Palavras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install notebook wordcloud pillow numpy bs4

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from wordcloud import wordcloud, STOPWORDS
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
# Baixar as stopwords (apenas na primeira execução)
nltk.download('stopwords')

# %%
# Abrir o arquivo de texto
with open('/nuvem.txt', 'r') as file:
    # Ler o conteúdo do arquivo
    nuvem = file.read()

# Exibir o conteúdo do arquivo
print(nuvem)
# Out:
# corretora de seguros saúde, já parou para pensar em como gerar leads qualificados pode impulsionar as vendas do seu negócio? Na Dataseek, nós temos a solução perfeita para você!Apresentador(a): Apresentamos o DataLeads, a solução revolucionária que vai transformar a forma como você gera leads B2B. Com nossa ferramenta Big Data, você terá acesso a informações precisas de telefones, e-mails e perfis do LinkedIn, permitindo uma comunicação certeira e um aumento exponencial nas suas vendas.ACom o DataLeads, você terá a vantagem competitiva que precisa para conquistar seu público-alvo e fechar negócios de forma eficiente.A Dataseek é uma startup especializada em fornecer soluções de Big Data e gestão de dados para empresas como a sua. Nossa missão é simplificar o processo de geração de leads, fornecendo informações valiosas e relevantes para impulsionar seus resultados.Apresentador(a): E o melhor de tudo? O DataLeads é rápido, fácil e descomplicado. Com apenas alguns cliques, você terá ac
# ...

# %%
import numpy as np

# %%
# Organizar numa lista de palavras

tokens = nuvem.split()
len (tokens)
# Out:
# 266

# %%
tokens[21]
# Out:
# 'Dataseek,'

# %%
# Conversão em minusculo
tokens = nuvem.split()

for i in range(len(tokens)):
    tokens[i] = tokens[i].lower().strip()

print(tokens)
# Out:
# ['corretora', 'de', 'seguros', 'saúde,', 'já', 'parou', 'para', 'pensar', 'em', 'como', 'gerar', 'leads', 'qualificados', 'pode', 'impulsionar', 'as', 'vendas', 'do', 'seu', 'negócio?', 'na', 'dataseek,', 'nós', 'temos', 'a', 'solução', 'perfeita', 'para', 'você!apresentador(a):', 'apresentamos', 'o', 'dataleads,', 'a', 'solução', 'revolucionária', 'que', 'vai', 'transformar', 'a', 'forma', 'como', 'você', 'gera', 'leads', 'b2b.', 'com', 'nossa', 'ferramenta', 'big', 'data,', 'você', 'terá', 'acesso', 'a', 'informações', 'precisas', 'de', 'telefones,', 'e-mails', 'e', 'perfis', 'do', 'linkedin,', 'permitindo', 'uma', 'comunicação', 'certeira', 'e', 'um', 'aumento', 'exponencial', 'nas', 'suas', 'vendas.acom', 'o', 'dataleads,', 'você', 'terá', 'a', 'vantagem', 'competitiva', 'que', 'precisa', 'para', 'conquistar', 'seu', 'público-alvo', 'e', 'fechar', 'negócios', 'de', 'forma', 'eficiente.a', 'dataseek', 'é', 'uma', 'startup', 'especializada', 'em', 'fornecer', 'soluções', 'de', 'big
# ...

# %%
tokens[21]
# Out:
# 'dataseek,'

# %%
# Baixar as stopwords (apenas na primeira execução)
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Tokenizar o texto em palavras
tokens = word_tokenize(palavras)

# Definir as stopwords em português
stopwords_pt = set(stopwords.words('portuguese'))

# %%
# Filtrar as palavras removendo as stopwords
palavras_filtradas = [palavra for palavra in tokens if palavra.lower() not in stopwords_pt]

# %%
# Juntar as palavras filtradas novamente em um texto
texto_filtrado = ' '.join(palavras_filtradas)

# %%
# Exibir o texto filtrado
print(texto_filtrado)
# Out:
# corretora seguros saúde , parou pensar gerar leads qualificados pode impulsionar vendas negócio ? dataseek , solução perfeita ! apresentador ( ) : apresentamos dataleads , solução revolucionária vai transformar forma gera leads b2b . ferramenta big data , acesso informações precisas telefones , e-mails perfis linkedin , permitindo comunicação certeira aumento exponencial vendas.acom dataleads , vantagem competitiva precisa conquistar público-alvo fechar negócios forma eficiente.a dataseek startup especializada fornecer soluções big data gestão dados empresas . missão simplificar processo geração leads , fornecendo informações valiosas relevantes impulsionar resultados.apresentador ( ) : melhor tudo ? dataleads rápido , fácil descomplicado . apenas alguns cliques , acesso leads qualificados , prontos serem abordados . perca tempo estratégias geração leads ultrapassadas . hora levar corretora seguros saúde próximo nível . chegou momento impulsionar negócio conquistar resultados extraor
# ...

# %%
# Preparando para wordcloud: uma String só com todas as palavras

palavras = " ".join(tokens)
palavras [:100]
# Out:
# 'corretora de seguros saúde, já parou para pensar em como gerar leads qualificados pode impulsionar a'

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
# Lista de stopwords personalizada
stopwords_customizada = STOPWORDS

# %%
# Nuvem sem Máscara
wordcloud = WordCloud(background_color='white',
                      stopwords=stopwords_customizada,
                      contour_width=1,
                      contour_color='white',
                      colormap='pink',
                      random_state=42)

wordcloud.generate(texto_filtrado)

# %%
wordcloud = WordCloud(background_color='white',
                      stopwords=stopwords_customizada,
                      contour_width=1,
                      contour_color='white',
                      colormap='Blues',
                      max_font_size=100,  # Ajuste o tamanho máximo da fonte desejado
                      random_state=42)
wordcloud.generate(texto_filtrado)

# %%
# Definir cores aleatórias para as palavras
def random_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return "hsl({}, {}%, {}%)".format(random.randint(0, 360), random.randint(60, 100), random.randint(50, 100))

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import random

# %%
# Recolorir as palavras na nuvem de palavras com cores aleatórias
wordcloud.recolor(color_func=random_color_func)

# %%
# Plotar a nuvem de palavras
plt.figure(figsize=(8,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
